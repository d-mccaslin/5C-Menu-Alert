# %%
import requests
from bs4 import BeautifulSoup
from collections import defaultdict
import re
from twilio.rest import TwilioRestClient

# %%
def get_menu():
    menu_url = "https://aspc.pomona.edu/menu/"
    response = requests.get(menu_url) #html from aspc website
    
    if response.status_code == 404:                 
        print("There was a problem with getting the page:")
        print(menu_url)
        
    data_from_url = response.text  # convert to text
    soup = BeautifulSoup(data_from_url, "html.parser") #convert to beautiful soup
    
    global L #list of all items that fall withing the tag li
    L = []
    Frank_dict=defaultdict(list)
    Frary_dict=defaultdict(list)
    Oldenborg_dict=defaultdict(list)
    CMC_dict=defaultdict(list)
    Scripps_dict=defaultdict(list)
    Pitzer_dict=defaultdict(list)
    Mudd_dict=defaultdict(list)
    Final_dict=defaultdict(dict)

    TRL = soup.findAll('tr')

    #Frank
    TDL = TRL[3].findAll('td')
    for tag in TDL: #Meal times
        meal=tag.findAll('span')
        first_meal=meal[0]
        mealstr=first_meal.next_element
        LIL=tag.findAll("li")
        menu_list=[]
        for item in LIL: #food items
            menu_items = item.next_element
            menu_items_str = str(menu_items)
            menu_list+=[menu_items]
        Frank_dict[mealstr]+=menu_list

    #Frary
    TDL = TRL[4].findAll('td')
    for tag in TDL: #Meal times
        meal=tag.findAll('span')
        first_meal=meal[0]
        mealstr=first_meal.next_element
        LIL=tag.findAll("li")
        menu_list=[]
        for item in LIL: #food items
            menu_items = item.next_element
            menu_items_str = str(menu_items)
            menu_list+=[menu_items]
        Frary_dict[mealstr]+=menu_list

    #Oldenborg
    TDL = TRL[5].findAll('td')
    for tag in TDL: #Meal times
        meal=tag.findAll('span')
        first_meal=meal[0]
        mealstr=first_meal.next_element
        LIL=tag.findAll("li")
        menu_list=[]
        for item in LIL: #food items
            menu_items = item.next_element
            menu_items_str = str(menu_items)
            menu_list+=[menu_items]
        Oldenborg_dict[mealstr]+=menu_list

    #CMC
    TDL = TRL[6].findAll('td')
    for tag in TDL: #Meal times
        meal=tag.findAll('span')
        first_meal=meal[0]
        mealstr=first_meal.next_element
        LIL=tag.findAll("li")
        menu_list=[]
        for item in LIL: #food items
            menu_items = item.next_element
            menu_items_str = str(menu_items)
            menu_list+=[menu_items]
        CMC_dict[mealstr]+=menu_list

    #Scripps
    TDL = TRL[7].findAll('td')
    for tag in TDL: #Meal times
        meal=tag.findAll('span')
        first_meal=meal[0]
        mealstr=first_meal.next_element
        LIL=tag.findAll("li")
        menu_list=[]
        for item in LIL: #food items
            menu_items = item.next_element
            menu_items_str = str(menu_items)
            menu_list+=[menu_items]
        Scripps_dict[mealstr]+=menu_list

    #Pitzer
    TDL = TRL[8].findAll('td')
    for tag in TDL: #Meal times
        meal=tag.findAll('span')
        first_meal=meal[0]
        mealstr=first_meal.next_element
        LIL=tag.findAll("li")
        menu_list=[]
        for item in LIL: #food items
            menu_items = item.next_element
            menu_items_str = str(menu_items)
            menu_list+=[menu_items]
        Pitzer_dict[mealstr]+=menu_list

    #Mudd
    TDL = TRL[9].findAll('td')
    for tag in TDL: #Meal times
        meal=tag.findAll('span')
        first_meal=meal[0]
        mealstr=first_meal.next_element
        LIL=tag.findAll("li")
        menu_list=[]
        for item in LIL: #food items
            menu_items = item.next_element
            menu_items_str = str(menu_items)
            menu_list+=[menu_items]
        Mudd_dict[mealstr]+=menu_list
    L=[Frank_dict]+[Frary_dict]+[Oldenborg_dict]+[CMC_dict]+[Scripps_dict]+[Pitzer_dict]+[Mudd_dict]
    return(L)

# %%
get_menu()
# Out:
# [defaultdict(list,
#              {'Breakfast': ['Pork Sausage Patty',
#                ' Vegetarian Sausage',
#                " O'Brien Potatoes",
#                ' Tofu Scramble',
#                ' Hard Boiled Eggs',
#                ' Scrambled Eggs',
#                ' Scrambled Egg Whites',
#                'Omelet Bar',
#                'Fruit Smoothies',
#                'Breakfast Special: Biscuit Sandwich warm buuttermilk',
#                ' scrambled eggs',
#                ' cheese',
#                ' Sausage Patty',
#                'Oatmeal with Toppings',
#                'Fruit and Yogurt Bar',
#                'Monkey Bread',
#                ' Banana Nut Bread'],
#               'Dinner': ['Burrito Bar: Chicken',
#                ' Carnitas',
#                ' Chile Relleno',
#                ' Mexican Rice & Pinto Beans',
#                ' Salsa Bar and Toppings',
#                'Italian Cold Cut Trio Sandwich',
#                'Cheese',
#                ' Pepperoni',
#                ' Vegetable Pizza',
#                ' Gluten Free Veggie',
#                'Burrito Bar: Chicken',
#                ' Carnitas',
#                ' Chile Relleno',
#                ' Mexican Rice & Pinto Beans',
#                ' Salsa Bar and Toppings',
#                'Split Pea and Ham',
#                'Arugula Beet and Goat Cheese',
#                'Chocolate Pudding',
#                ' Oatmeal Cookies',
#                ' Vegan Vanilla Cupcakes'],
#               'Lunch': ['Chicken Tenders',
#                ' Marinated Grilled Tofu Steak',
#                ' Baked Potato with Butter/Sour Cream/and Chives',
#                ' Steamed Broccoli',
#                ' Steakhouse Spinach',
#                ' Dinner Roll',
#                'Pupusas',
#                'Asiago Roast Beef Melt',
#                ' Toasted Caprese Sandwich',
#                'Burgers',
#                ' Garden Burgers',
#                ' Spicy Black Bean Burgers',
#                ' Turkey Burgers',
#                ' Chicken Breast',
#                ' Hot Dogs',
#                ' French Fries',
#                ' Onion Rings',
#                ' Toppings',
#                'Baked Stuffed Potato',
#                'Strawberry Feta',
#                'Cream Brulee',
#                ' Pecan Diamonds',
#                ' Vegan Vanilla Cupcakes']}),
#  defaultdict(list,
#              {'Breakfast': ['Bacon',
#                ' Vegetarian Sausage',
#                ' Hash Brown Potatoes',
#                ' Tofu Scramble',
#                ' Hard Boiled Eggs',
#                ' Scrambled Eggs',
#                ' Scrambled Egg Whites',
#                'Omelet Bar',
#                'Fruit Smoothies',
#                'Breakfast Special: English Muffin Breakfast Sandwich with bacon',
#                ' scarmbeld eggs & cheese',
#                'Gluten Free Oatmeal',
#                ' Toppings: Brown Sugar',
#                ' Raisins',
#                ' Cinnamon Sugar',
#                'Bagel',
#                ' Fruit & Yogurt Bar',
#                " Frank's Granola",
#                ' Breakfast Muesli',
#                'Monkey Bread',
#                ' Banana Nut Bread'],
#               'Dinner': ['Grilled Tri Tip',
#                ' Vegan Sloppy Joes',
#                ' Macaroni and Cheese',
#                ' Roasted Potato Wedges',
#                ' Corn on the Cob',
#                ' Asparagus Medley',
#                '\n',
#                'Pad Thai',
#                'Cheese',
#                ' Pepperoni',
#                ' Vegetable Pizza',
#                'Chicken Tender Sandwich',
#                '12 Veggies Soup',
#                'Cranberry Spinach Salad',
#                'Chocolate Pudding',
#                ' Oatmeal Cookies',
#                ' Vegan Vanilla Cupcakes'],
#               'Lunch': ['Tacos: Marinated Chicken',
#                ' Beef Barbacoa',
#                ' Mexican Rice',
#                ' Refried Beans',
#                ' Soyrizo with Potatoes and Green Chili',
#                ' Steamed Vegetables',
#                'BBQ Chopped Chicken Salad or Wrap',
#                'Toasted Sub Bar',
#                'Chili Cheese Fries with Garlic Aioli & Fried Egg (upon request)',
#                'Broccoli Cheddar',
#                'Mixed Green Salad with Oranges and Pecans',
#                'Creme Brule',
#                ' Pecan Diamonds',
#                ' Vegan Vanilla Cupcakes']}),
#  defaultdict(list,
#              {'Breakfast': ['Closed.'],
#               'Dinner': ['Closed.'],
#               'Lunch': ['Egg Drop Soup',
#                'Sweet & Sour Chicken',
#                'Vegetarian Stir Fry Udon / Vegetable Spring Rolls',
#                'Steamed Rice',
#                'Steamed Broccoli',
#                'Cheese, Pepperoni',
#                'Lettuce Variety, Fresh Cut Vegetables, Hand Made Dressings & Fresh Fruits',
#                'Your Sandwich & Panini Made Your Way',
#                'Sweets, Cookies, Homemade Cakes, Pies & Other Treats']}),
#  defaultdict(list,
#              {'Breakfast': ['Chocolate Chip Muffins',
#                '\nBagels,\nAssorted Pastries',
#                'Cage Free Hard-Boiled Eggs,\nMade To Order Omelet Station',
#                'Make Your Own Waffle Station',
#                'Oatmeal & Cream Of Wheat',
#                'Scrambled Eggs',
#                'Chorizo And Eggs',
#                'Turkey Bacon & Sausage Links',
#                'Chocolate Chip Pancakes',
#                'Homemade Potatoes'],
#               'Dinner': ['Pasta Express',
#                'Pork Shard Sou Served With Jasmine Rice',
#                'Edamame',
#                'And Green Beans',
#                'Egg Foo Yon',
#                'Vegan Spreads',
#                'Pesto & Oils,\nHummus & Pita Bread',
#                'Aguas Frescas',
#                'And All Natural No Sugar Added Spa Water',
#                'Butternut Squash & Mushroom Cakes Served With French Bean And Jasmine Rice',
#                'Dried Fruit Rice Salad',
#                'Grilled Asparagus And Red Roasted Peppers Salad',
#                'Pizzas Made To Order',
#                'Smoked Turkey & Collard Greens Soup',
#                'Artichoke And Spring Garlic Soup',
#                'Sautéed Sizzle',
#                'Customize Your Flatbread Pizza',
#                'Grilled Chicken Breast',
#                'Hamburgers',
#                'Vegetarian Burgers & Hot Dogs',
#                'Churros',
#                'Artisan Burger Served On An Onion Bun',
#                'Chocolate Chip Cookies',
#                'Coconut Snowballs',
#                'Blueberry Bar',
#                'Marble Cake',
#                'Molten Cake',
#                'Vegan Chocolate Cupcakes',
#                'Made Without Gluten Double Chocolate Cookies'],
#               'Lunch': ['Pasta Express',
#                'Pork Chops Served With Fresh Cranberry Relish',
#                'Black Quinoa Pilaf',
#                'And Medley Vegetables',
#                'Vegetarian Creamy Pasta Carbonara',
#                'Vegan Spreads',
#                'Pesto & Oils,\nHummus & Pita Bread',
#                'Aguas Frescas',
#                'And All Natural No Sugar Added Spa Water',
#                'Quinoa Bolognese Spaghetti Served With Black Bean And Calrose Rice',
#                'Dried Fruit Rice Salad',
#                'Grilled Asparagus And Red Roasted Peppers Salad',
#                'Nacho Bar Served With Ground Beef',
#                'Olives',
#                'Tomatoes',
#                'Jalapeño',
#                'And Salsa',
#                'Caldo De Camarón (Shrimp Soup)',
#                'Vegan French Onion Soup',
#                'Little Italy',
#                'Cheese Pizza',
#                'Pepperoni Pizza',
#                'Pesto Basil Pizza Served With Sliced Tomatoes And Feta Cheese',
#                '\nChocolate Chip Cookies',
#                'Grilled Chicken Breast',
#                'Hamburgers',
#                'Vegetarian Burgers & Hot Dogs',
#                'Churros',
#                'Chicken Burger',
#                'Chocolate Chip Cookies',
#                'Coconut Snowballs',
#                'Blueberry Bar',
#                'Marble Cake',
#                'Molten Cake',
#                'Vegan Chocolate Cupcakes',
#                'Made Without Gluten Double Chocolate Cookies']}),
#  defaultdict(list,
#              {'Breakfast': ['Steel Cut Oatmeal',
#                'Omelet Bar',
#                'Scrambled  Eggs',
#                'Scrambled Tofu',
#                'Sticky Rice',
#                'Frizzled Ham',
#                'Vegetarian Sausage Patty',
#                "O'Brien Potatoes",
#                'Chilaquiles with Fire Roasted Salsa',
#                'Blueberry Pancakes',
#                'Breakfast Burrito w/Chorizo',
#                'Assorted Mini Danish (CS)',
#                'Assorted Petite Muffins'],
#               'Dinner': ['Chickpea & Barley Salad',
#                'Roasted Corn & Vegetable Succotash Salad',
#                'Baked  Potato',
#                'Beer Battered Onion Rings',
#                'Grilled Yellow Onions',
#                'Sauteed Mushrooms',
#                'California Mixed Vegetable',
#                'Top Sirloin Steak, Raw, 6 oz',
#                'Herbed Grilled Salmon',
#                'Mongolian Wok',
#                'Baked Chicken Adobo',
#                'Jasmine   Rice',
#                'Fresh Green Beans',
#                'Pinto  Bean',
#                'Mexican Vegetable Quesadilla',
#                'Colache',
#                'Baby Carrots',
#                'Brown  Rice',
#                'Vegan Six Bean Soup',
#                'Mexican Chicken Lime Soup',
#                'Allergy Free Pork'],
#               'Lunch': ['Chickpea & Barley Salad',
#                'Roasted Corn & Vegetable Succotash Salad',
#                'Habanero Salsa',
#                'Fire Roasted Tomato Salsa',
#                'Salsa Verde',
#                'Citrus Sour Cream Sauce',
#                'Cold Cabbage Salad',
#                'Lemon Wedge',
#                'Baja Fish Taco',
#                'Baja Black Bean',
#                'Mexican Fiesta  Rice',
#                'Pasta Toss Bar',
#                'BBQ Rotisserie Chicken',
#                'Roast Sweet Potatoes',
#                'Southern Style Collard Greens',
#                'Tuscan White Bean Stew',
#                'Zucchini & Mushroom Frittata',
#                'Roasted Fresh Asparagus',
#                'Garlic Roasted Grape Tomatoes',
#                'Cooked Quinoa',
#                'Vegan Six Bean Soup',
#                'Mexican Chicken Lime Soup',
#                'Allergy Free Sirloin Steak']}),
#  defaultdict(list,
#              {'Breakfast': ['Scrambled Eggs',
#                'Vegetarian Sausage',
#                'Hot Oatmeal',
#                'Hard Boil Eggs',
#                'Potato Hash Browns',
#                'Potato Tater Tots',
#                'Turkey Sausage',
#                'Vegetable Lentil',
#                'Cinnamon Cheese Blintz',
#                'Beef Chorizo Burrito'],
#               'Dinner': ['Beef Chili',
#                'Butternut Squash Soup',
#                'Crispy Chicken Caesar Salad',
#                'Pitzer 1 Bowl &#38; Burrushi',
#                'A.M. In The P.M.',
#                'Grilled Steak',
#                'Grilled Steak',
#                'Aztec Grain Stuffed Cabbage',
#                'Rosemary &#38; Garlic Mashed Cauliflower',
#                'Sauteed Collard Greens',
#                'Roasted Acorn Squash'],
#               'Lunch': ['Beef Chili',
#                'Butternut Squash Soup',
#                'Coconut Ginger Chicken Bowl',
#                'Pitzer Pasta Bar',
#                'Huli Huli Bbq Pork Loin',
#                'Huli Huli Barbeque Pork Loin',
#                'Roasted Tempeh',
#                'Roasted Red Potatoes',
#                'Sauteed Spinach',
#                'Steamed Rainbow Carrots']}),
#  defaultdict(list,
#              {'Breakfast': ['Oatmeal with Toppings',
#                'Blueberry Mini Scone',
#                'Chocolate Chunk Muffins',
#                'Banana Strawberry Yogurt Smoothie',
#                'Scrambled Eggs with Margarine',
#                'Hard Cooked Cage Free Egg',
#                'Fried  Egg',
#                'Scrambled Tofu',
#                'French Waffle',
#                'Sausage Gravy & Biscuit',
#                'Crisp Bacon Slices',
#                'Spinach & Mushroom Omelet',
#                'Mexican Breakfast Potato',
#                'Breakfast Burrito with Salsa',
#                'Plain Bagel',
#                'Petite Croissants',
#                'Cranberry-Apple Strudel'],
#               'Dinner': ['Roasted Garden Vegetable Soup',
#                'Caldo Gallego Soup',
#                'Caribbean Carrot & Sweet Potato Soup',
#                'Herb Seasoned Breadsticks',
#                'HMC Muddgolian Beef  Wok',
#                'HMC Muddgolian Tofu Wok',
#                'HMC Muddgolian Chicken Wok',
#                'Quesadilla Bar',
#                'Scrambled Eggs with Cheddar',
#                'Scrambled Egg',
#                'Scrambled Tofu',
#                'Crisp  Bacon',
#                'Sausage Links',
#                'French Fried Tater Tots',
#                'Chocolate Chip Pancakes',
#                'Belgian Waffles',
#                'Sausage Gravy & Biscuit',
#                'Golden Fried Chicken Breast',
#                'Fresh Grilled Vegetables',
#                'Steamed Broccoli & Cauliflower',
#                'Rice and Orzo Pilaf',
#                'Southern-Style Biscuit',
#                'Eggplant Parmesan',
#                'Gnocchi Casserole',
#                'Made to Order Deli Bar',
#                'Roasted Corn & Vegetable Succotash Salad',
#                'Funnel Cake Sundae Bar',
#                "Chocolate Brownies with M & M's",
#                'Strawberry Jell-O Parfait',
#                'Chocolate Pudding Cup',
#                'Salvadoran Chicken',
#                'Brown  Rice',
#                'Green Beans with Oregano'],
#               'Lunch': ['Roasted Garden Vegetable Soup',
#                'Caldo Gallego Soup',
#                'Caribbean Carrot & Sweet Potato Soup',
#                'Herb Seasoned Breadsticks',
#                'Made to Order Salad',
#                'Shrimp Scampi & Linguine Pasta Bowl',
#                'Turkey Cobb Biggie Sandwich',
#                'Black Bean, Corn & Jicama Salad',
#                'Burger Bar',
#                'Chicken Patty Sandwich',
#                'Grilled Chicken Breast',
#                'All-Meat Franks',
#                'Crisp Bacon Slices',
#                'Grilled Cheese Sandwiches',
#                'Veggie Burger on Bun',
#                'Peruvian Lime Chicken Breast',
#                'Steamed Corn',
#                'Zucchini & Tomatoes',
#                'Roja Roasted Potatoes',
#                'Curried Tofu with Jasmine Rice',
#                'Cauliflower Tofu Curry',
#                'Made to Order Deli Bar',
#                'Roasted Corn & Vegetable Succotash Salad',
#                'Lucky Charms Cereal Bars',
#                'Creamy Pineapple Nut Squares',
#                'Black Forest Brownies',
#                'Banana Cream Pie Pudding Cup',
#                'Strawberry Jell-O Parfait',
#                'Chocolate Chip Cookie',
#                'Vanilla Pudding Cup',
#                'Simple Pork Green Chile',
#                'Coastal Style White Rice',
#                'Roasted Corn']})]

# %%
def match_food(item):
    L=get_menu()
    halls=['Frank', 'Frary', 'Oldenborg', 'CMC', 'Scripps', 'Pitzer', 'Mudd']
    
    for i in range(len(L)):
        for x in item:
            if x in L[i]['Breakfast']:
                print ( str(halls[i])+' has '+x+' for breakfast')
                return ( str(halls[i])+' has '+x+' for breakfast')
            if x in L[i]['Lunch']:
                print ( str(halls[i])+' has '+x+' for lunch')
                return ( str(halls[i])+' has '+x+' for lunch')
            if x in L[i]['Dinner']:
                print ( str(halls[i])+' has '+x+' for dinner')
                return ( str(halls[i])+' has '+x+' for dinner')

# %%
pasta = match_food(["Pasta Express", "Bacon", "Burger Bar"])
# Out:
# Frary has Bacon for breakfast.Frary has Bacon for lunch.Frary has Bacon for dinner.

# %%
str(pasta)
# Out:
# 'Frary has Bacon for breakfast'

# %%
ACCOUNT_SID = "AC9629dc758c9d995440c7b90b5542d86c" 
AUTH_TOKEN = "b13ff78cc4235ddbabcf41decd4269ee" 
 
client = TwilioRestClient(ACCOUNT_SID, AUTH_TOKEN) 
 
client.messages.create(
    to="+14065797877", 
    from_="+17797747983", 
    body=pasta, 
)
